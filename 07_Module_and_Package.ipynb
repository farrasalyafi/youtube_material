# %% [markdown]
# # **------------------------------------------- 07 --------------------------------------------**
# # **---------------------------- MODULE & PACKAGE ----------------------**
#
# Notebook ini merupakan salah satu dari series #BelajarDataScience yang dibuat oleh Muhammad Farras Alyafi khusunya untuk yang tidak memiliki latar belakang IT, statistika ataupun matematika. Notebook dan juga youtube seriesnya diusahakan dibuat semudah mungkin agar mudah dipahami. Semoga notebook ini bermanfaat. Silahkan bagikan notebook ini dan jangan lupa cek video lainya di link berikut:
#
# https://youtu.be/F2VmHPqdxEM

# %% [markdown]
# # 1. Module
#
# Module itu adalah kumplan codingan yang berisi kumpulan class, function global variabel dll yang disimpan dalam format ".py". Intinya script atau codingan kita yang kita mau pakai di project lainya tanpa perlu menuliskanya dari awal atau copy-paste lagi

# %% [markdown]
# # 2. Package
#
# Kalo package adalah sebuah directory yang isinya kumpulan dari module-module dan memiliki "__ init __.py ".Kegunaan package adalah memudahkan kita untuk mengoranisir module yang kita punya.

# %% [markdown]
# # 3. Library
#
# Library sebernernya hampir sama aja kayak packagae, cuma ibaratnya kalo library kayak kumpulan package. Tapi secara konsepdia sama aja kayak package.

# %%
from IPython.display import Image 

Image('https://data-flair.training/blogs/wp-content/uploads/sites/2/2018/02/Package-Module-Structure.png')

# %% [markdown]
# ### ------------------- Contoh Module Dan Package ---------------------------
#
# -->matematika(Package)
#
# ----> __ init __.py(Constructot/Initializer)
#
# ---->penjumlahan.py(Module)
#
# ---->pengurangan.py(Module)
#
# ---->perkalian.py(Module)
#
# ---->pembagian.py(module)
#
# -------->aljabar(Sub Package)
#
# ------------>__ init __.py(Constractor/Initializer)
#
# ------------>vektor.py(Module)
#
# ------------>matriks.py(Moduel)
